# %% [markdown]
# # Confronto fra evapotraspirazione di due colture diverse

# %%
act3 = pd.read_csv('ActualEvapoTranspiration_PT_3.csv',skiprows=6, sep=',', parse_dates=[0], na_values=-9999,usecols=[1,2])
act3.columns = ['Datetime','EvapoTranspiration']

fig = px.line()
fig.add_trace(go.Scatter(x=act3['Datetime'], y=act3['EvapoTranspiration'], mode='lines', name='broccoli'))
fig.add_trace(go.Scatter(x=act['Datetime'], y=act['EvapoTranspiration'], mode='lines', name='pistacchio'))

fig.update_layout(
    title='Priestley-Taylor EvapoTranspiration of two different coltures compared',
    xaxis_title="Time",
    yaxis_title="EvapoTranspiration [mm]",)
fig.update_xaxes(rangeslider_visible=True)
fig.show()

# %% [markdown]
# La differenza tra i tipi di colture diverse tra loro ha un grande impatto sull'evapotraspirazione. La differente capacità di traspirare delle due piante prese in esame è evidente dal grafico.
